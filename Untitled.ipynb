# %% [markdown]
# # **Global Air Quality Index: Analyzing Pollution Patterns Across the World**
#
# ## **Business Understanding**
#
# ### **Overview**
# Air quality is an increasingly vital global issue affecting public health, environmental sustainability, and overall quality of life. Various pollutants such as PM2.5, CO, NO2, and Ozone contribute to the decline in air quality, especially in urban areas where industrialization and vehicular emissions are rampant. This dataset provides a snapshot of air quality measurements across cities worldwide, allowing us to assess the severity of pollution, identify patterns, and propose actionable solutions.
#
# Our goal is to analyze this data to better understand how air pollution varies by location and pollutant type, helping stakeholders like governments, researchers, and the public to make informed decisions for reducing air pollution and protecting human health.
#
# ### **Problem Statement**
# Air pollution remains one of the most significant environmental and public health challenges globally. With rising industrial activities and increased urbanization, maintaining good air quality has become difficult in many cities. Poor air quality can lead to severe health problems such as respiratory diseases, cardiovascular conditions, and premature death. Understanding the extent of air pollution and its distribution across different regions is essential to developing policies and interventions aimed at improving air quality.
#
# By analyzing air quality data, we seek to determine which cities are most affected by pollution, the main pollutants contributing to these levels, and the impact of geographic and environmental factors on air quality.
#
# ---
#
# ## **Objectives**
#
# ### **Main Objective**
# The primary goal of this analysis is to assess the air quality across various global cities and derive actionable insights from the concentrations of different pollutants, with the aim of identifying trends, pollution hotspots, and providing data-driven recommendations for mitigating pollution.
#
# ### **Specific Objectives**
# 1. **Evaluate AQI Levels**: Analyze the overall Air Quality Index (AQI) values and categories across different cities to determine the most and least polluted areas.
# 2. **Analyze Pollutant-Specific Data**: Investigate the AQI values of specific pollutants (CO, Ozone, NO2, PM2.5) to understand their individual contributions to air pollution.
# 3. **Categorize Air Quality**: Classify the cities based on AQI categories (e.g., Good, Moderate, Unhealthy) and analyze the distribution of these categories globally.
# 4. **Perform Geospatial Analysis**: Use geographical coordinates (latitude and longitude) to visualize the spread of air quality levels across the globe, identifying pollution hotspots.
# 5. **Identify Trends**: Explore patterns over time and across regions to detect trends in pollution levels, determining which regions are improving and which are deteriorating.
#
# ---
#
# ## **Data Understanding**
#
# ### **Dataset Overview**
# The dataset contains detailed air quality data from cities around the world, measuring multiple pollutants and their corresponding Air Quality Index (AQI) values. This data allows us to assess overall air quality, as well as the specific impact of individual pollutants like CO, Ozone, NO2, and PM2.5.
#
# Each row in the dataset represents air quality readings from a specific city on a given day. AQI categories classify these readings into health impact categories (e.g., 'Good', 'Moderate', 'Unhealthy'), providing a holistic view of the air quality in each region.
#
# ---
#
# ### **Columns in the Dataset**
#
# | **Column Name**         | **Description**                                                                                  |
# |-------------------------|--------------------------------------------------------------------------------------------------|
# | **Country**             | The country where the city is located.                                                           |
# | **City**                | The city in which the air quality was measured.                                                  |
# | **AQI Value**           | The overall Air Quality Index value representing the air quality level.                           |
# | **AQI Category**        | Categorical label classifying the AQI value (e.g., 'Good', 'Moderate', 'Unhealthy').              |
# | **CO AQI Value**        | Air Quality Index value for **Carbon Monoxide (CO)** concentration.                              |
# | **CO AQI Category**     | Categorical label classifying the AQI for **CO**.                                                |
# | **Ozone AQI Value**     | Air Quality Index value for **Ozone** concentration.                                             |
# | **Ozone AQI Category**  | Categorical label classifying the AQI for **Ozone**.                                             |
# | **NO2 AQI Value**       | Air Quality Index value for **Nitrogen Dioxide (NO2)** concentration.                            |
# | **NO2 AQI Category**    | Categorical label classifying the AQI for **NO2**.                                               |
# | **PM2.5 AQI Value**     | Air Quality Index value for **Particulate Matter (PM2.5)** concentration (particles < 2.5 µm).    |
# | **PM2.5 AQI Category**  | Categorical label classifying the AQI for **PM2.5**.                                             |
# | **lat**                 | Latitude of the city, useful for geospatial analysis.                                             |
# | **lng**                 | Longitude of the city, useful for geospatial analysis.                                            |

# %% [markdown]
# ## Import necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load data
data = pd.read_csv('AQI and Lat Long of Countries.csv')
data.head()
# Out:
#               Country              City  AQI Value AQI Category  CO AQI Value  \
# 0  Russian Federation        Praskoveya         51     Moderate             1
# 1              Brazil  Presidente Dutra         41         Good             1
# 2              Brazil  Presidente Dutra         41         Good             1
# 3               Italy   Priolo Gargallo         66     Moderate             1
# 4              Poland         Przasnysz         34         Good             1
#
#   CO AQI Category  Ozone AQI Value Ozone AQI Category  NO2 AQI Value  \
# 0            Good               36               Good              0
# 1            Good                5               Good              1
# 2            Good                5               Good              1
# 3            Good               39               Good              2
# 4            Good               34               Good              0
#
#   NO2 AQI Category  PM2.5 AQI Value PM2.5 AQI Category      lat      lng
# ...

# %% [markdown]
# The dataset shows air quality data for several cities:
#
# - **Praskoveya, Russia**: AQI Value of **51 (Moderate)**, with **Good** levels for CO, Ozone, and NO2. PM2.5 is **Moderate**.
# - **Presidente Dutra, Brazil**: AQI Value of **41 (Good)**, with all pollutants in the **Good** category.
# - **Priolo Gargallo, Italy**: AQI Value of **66 (Moderate)**, with CO, Ozone, and NO2 all **Good**, but PM2.5 is **Moderate**.
# - **Przasnysz, Poland**: AQI Value of **34 (Good)**, and all pollutants fall within the **Good** range.
#
# These results highlight varying air quality levels, ranging from **Good** to **Moderate**, with specific pollutants being well controlled.

# %%
data.columns
# Out:
# Index(['Country', 'City', 'AQI Value', 'AQI Category', 'CO AQI Value',
#        'CO AQI Category', 'Ozone AQI Value', 'Ozone AQI Category',
#        'NO2 AQI Value', 'NO2 AQI Category', 'PM2.5 AQI Value',
#        'PM2.5 AQI Category', 'lat', 'lng'],
#       dtype='object')

# %%
data.describe()
# Out:
#           AQI Value  CO AQI Value  Ozone AQI Value  NO2 AQI Value  \
# count  16695.000000  16695.000000     16695.000000   16695.000000
# mean      62.998682      1.342138        31.767355       3.819647
# std       43.091971      2.371379        22.839343       5.880677
# min        7.000000      0.000000         0.000000       0.000000
# 25%       38.500000      1.000000        20.000000       0.000000
# 50%       52.000000      1.000000        29.000000       2.000000
# 75%       69.000000      1.000000        38.000000       5.000000
# max      500.000000    133.000000       222.000000      91.000000
#
#        PM2.5 AQI Value           lat           lng
# count     16695.000000  16695.000000  16695.000000
# mean         59.821324     30.267148     -3.944485
# std          43.208298     22.947398     73.037148
# min           0.000000    -54.801900   -171.750000
# 25%          34.000000     16.515450    -75.180000
# 50%          52.000000     38.815800      5.643100
# ...

# %% [markdown]
# ### **Summary of Air Quality Data**
#
# - **AQI Value**: Average of 63 (Moderate), ranging from **7** (Good) to **500** (Hazardous), with variability across regions (std: 43).
# - **CO AQI Value**: Low average of **1.34**, with a max of **133** in some polluted areas.
# - **Ozone AQI Value**: Average of **31.77** (Good), max of **222**, indicating occasional spikes.
# - **NO2 AQI Value**: Low mean of **3.82**, with a maximum of **91** in certain locations.
# - **PM2.5 AQI Value**: Moderate average of **59.82**, reaching a max of **500** in some highly polluted areas.
#
# Geographical variation is also present, as seen from the latitude and longitude range.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16695 entries, 0 to 16694
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             16393 non-null  object
#  1   City                16695 non-null  object
#  2   AQI Value           16695 non-null  int64
#  3   AQI Category        16695 non-null  object
#  4   CO AQI Value        16695 non-null  int64
#  5   CO AQI Category     16695 non-null  object
#  6   Ozone AQI Value     16695 non-null  int64
#  7   Ozone AQI Category  16695 non-null  object
#  8   NO2 AQI Value       16695 non-null  int64
#  9   NO2 AQI Category    16695 non-null  object
#  10  PM2.5 AQI Value     16695 non-null  int64
#  11  PM2.5 AQI Category  16695 non-null  object
#  12  lat                 16695 non-null  float64
#  13  lng                 16695 non-null  float64
# dtypes: float64(2), int64(5), object(7)
# memory usage: 1.8+ MB

# %%
#  Check for Missing Values

# %%
data.isnull().sum()
# Out:
# Country               302
# City                    0
# AQI Value               0
# AQI Category            0
# CO AQI Value            0
# CO AQI Category         0
# Ozone AQI Value         0
# Ozone AQI Category      0
# NO2 AQI Value           0
# NO2 AQI Category        0
# PM2.5 AQI Value         0
# PM2.5 AQI Category      0
# lat                     0
# lng                     0
# dtype: int64

# %% [markdown]
# The dataset has **302 missing values** in the **Country** column, while all other columns, including **City**, **AQI values**, pollutant categories (CO, Ozone, NO2, PM2.5), and geographical coordinates (**lat**, **lng**), are complete with no missing values.

# %%
data.dropna(axis=1, inplace=True)

# %% [markdown]
#  ## EDA

# %% [markdown]
# ### Univariate

# %%
#1. Numerical Columns (e.g., AQI Values, lat, lng)
# For each numerical column, we can look at distributions and summary statistics.
# Summary Statistics:

# %%
data[['AQI Value', 'CO AQI Value', 'Ozone AQI Value', 'NO2 AQI Value', 'PM2.5 AQI Value', 'lat', 'lng']].describe()
# Out:
#           AQI Value  CO AQI Value  Ozone AQI Value  NO2 AQI Value  \
# count  16695.000000  16695.000000     16695.000000   16695.000000
# mean      62.998682      1.342138        31.767355       3.819647
# std       43.091971      2.371379        22.839343       5.880677
# min        7.000000      0.000000         0.000000       0.000000
# 25%       38.500000      1.000000        20.000000       0.000000
# 50%       52.000000      1.000000        29.000000       2.000000
# 75%       69.000000      1.000000        38.000000       5.000000
# max      500.000000    133.000000       222.000000      91.000000
#
#        PM2.5 AQI Value           lat           lng
# count     16695.000000  16695.000000  16695.000000
# mean         59.821324     30.267148     -3.944485
# std          43.208298     22.947398     73.037148
# min           0.000000    -54.801900   -171.750000
# 25%          34.000000     16.515450    -75.180000
# 50%          52.000000     38.815800      5.643100
# ...

# %%
# List of columns to plot
columns = ['AQI Value', 'CO AQI Value', 'Ozone AQI Value', 'NO2 AQI Value', 'PM2.5 AQI Value']

# Create subplots
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

# Flatten the axs array for easy iteration
axs = axs.ravel()

# Loop over each column and create histograms with Matplotlib
for i, col in enumerate(columns):
    axs[i].hist(data[col].dropna(), bins=30)  # Using .dropna() to avoid NaN issues
    axs[i].set_title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# The graphs represent the distribution of values across different features or variables from a dataset. Here's a general explanation of their appearance:
#
# 1. **Skewness**: All five histograms are heavily skewed to the right. This means that most of the data points are concentrated towards the lower values, while a few outliers stretch the distribution towards the higher end. Such skewness is common with variables that cannot go below zero but have no clear upper bound.
#
# 2. **Peaks and Frequency**: Each histogram has a distinct peak (the mode), which shows the range where most data points fall. After this peak, the frequencies of occurrences rapidly decline as values increase, suggesting that the majority of the data is concentrated in the lower ranges.
#
# 3. **Similar Patterns**: While the specific ranges and scales may differ across the graphs, they all share a similar pattern of right-skewed distribution. This consistency could imply that the features being represented have similar data characteristics.
#
# 4. **Potential Outliers**: The long tails in each histogram hint at the presence of potential outliers or extreme values that are significantly larger than the bulk of the data. These outliers could disproportionately affect statistical analyses, so it's important to handle them appropriately, possibly by applying transformations or using robust statistics.
#
# In conclusion, these histograms show right-skewed distributions with most data concentrated at lower values and long tails extending to the right, indicating the presence of high-value outliers.

# %%
data['AQI Category'].value_counts()
data['CO AQI Category'].value_counts()
data['Ozone AQI Category'].value_counts()
data['NO2 AQI Category'].value_counts()
data['PM2.5 AQI Category'].value_counts()
# Out:
# PM2.5 AQI Category
# Good                              7936
# Moderate                          6882
# Unhealthy for Sensitive Groups     881
# Unhealthy                          828
# Very Unhealthy                     115
# Hazardous                           53
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='AQI Category', order=data['AQI Category'].value_counts().index)
plt.show()

# %% [markdown]
# The bar chart represents the distribution of values across five distinct categories on the x-axis, with their corresponding frequencies or counts shown on the y-axis.
#
# ### Observations:
# 1. **First and Second Categories (Blue and Orange Bars)**:
#    - These two categories have the highest frequencies, as their bars are the tallest.
#    - They dominate the chart, with the blue bar slightly taller than the orange one.
#
# 2. **Remaining Three Categories (Green, Red, Purple, and Brown Bars)**:
#    - The green and red bars are shorter, indicating lower frequencies compared to the first two categories.
#    - The purple and brown bars are the smallest, representing the least frequent categories in the dataset.

# %% [markdown]
# ## Bivariate

# %%
# Numerical vs. Numerical

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='AQI Value', y='PM2.5 AQI Value', data=data)
plt.title('AQI Value vs PM2.5 AQI Value')
plt.show()

# %% [markdown]
# This scatter plot displays a strong positive linear relationship, with most data points clustered along a diagonal line. A few outliers deviate from this trend, particularly toward the upper right. The x and y axes likely represent two continuous variables with similar scaling.

# %%
# Numerical vs. Categorical

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='AQI Category', y='AQI Value', data=data)
plt.title('AQI Value across AQI Categories')
plt.show()

# %%
# Compare averages of numerical variables grouped by categories

# %%
plt.figure(figsize=(10, 6))
data.groupby('AQI Category')['AQI Value'].mean().plot(kind='bar')
plt.title('Mean AQI Value by AQI Category')
plt.show()

# %% [markdown]
# This bar chart shows varying levels of categories, with one category significantly higher than the others. The tallest bar indicates a peak or dominant category, while the remaining bars display smaller, yet differing values. This suggests a distribution where one aspect strongly stands out compared to the rest, which may require focused attention or analysis.

# %%
#  Geospatial Analysis (lat, lng)

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='lng', y='lat', hue='AQI Category', data=data)
plt.title('Geospatial Plot of AQI Categories')
plt.show()

# %% [markdown]
# This graph displays a global map illustrating various Air Quality Index (AQI) categories represented by color-coded dots. The AQI is a measure of air pollution levels and its potential impact on human health. The legend on the right explains the categories:
#
# - **Blue (Moderate)**: AQI levels indicate that air quality is generally acceptable, but there may be a concern for a very small number of sensitive individuals.
# - **Green (Good)**: Air quality is considered satisfactory, and air pollution poses little or no risk.
# - **Red (Unhealthy)**: Everyone may experience health effects; members of sensitive groups may experience more serious health effects.
# - **Purple (Very Unhealthy)**: Health alert—everyone may experience more serious health effects.
# - **Orange (Unhealthy for Sensitive Groups)**: Sensitive groups may experience health effects, but the general public is less likely to be affected.
# - **Maroon (Hazardous)**: Health warnings of emergency conditions. The entire population is more likely to be affected.
#
# The map shows that air quality varies across different regions globally. Areas with higher concentrations of orange and red dots indicate regions with more significant air quality concerns, while blue and green dots suggest regions with generally good to moderate air quality.
#
# Key observations include:
# - A large number of regions in Africa, parts of South America, and South Asia show moderate AQI levels.
# - Regions in the United States, Europe, and parts of China display a mix of good and moderate air quality.
# - Some clusters, particularly in Southeast Asia, show more concerning levels of unhealthy or very unhealthy air quality.
#
# This visualization helps identify global trends in air quality and highlights areas where air pollution is a more severe concern.

# %%
# Correlation Matrix

# %%
corr_matrix = data[['AQI Value', 'CO AQI Value', 'Ozone AQI Value', 'NO2 AQI Value', 'PM2.5 AQI Value']].corr()
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of AQI Values')
plt.show()

# %% [markdown]
# ### **Overall Conclusion**
#
# The comprehensive analysis of the global air quality dataset offers valuable insights into air pollution patterns and their implications:
#
# - **Air Quality Overview**: The majority of the data falls within the "Good" to "Moderate" categories, reflecting relatively acceptable air quality across many regions. However, there are notable instances of higher AQI values that indicate poorer air quality in certain areas.
#
# - **Pollutant Analysis**: **PM2.5, NO2, CO,** and **Ozone** are identified as major contributors to air pollution. The correlations among these pollutants suggest shared sources and interactions, providing a deeper understanding of their combined effects on air quality.
#
# - **Geographic Distribution**: The global map highlights significant variations in air quality. Areas with higher concentrations of **red, orange,** and **purple** dots indicate regions with severe air quality concerns. In contrast, **blue** and **green** dots suggest better air quality conditions. Notably, regions such as parts of Africa, South America, and South Asia show moderate AQI levels, while clusters in Southeast Asia and other areas reflect more concerning pollution levels.
#
# - **Targeted Interventions**: The findings point to specific countries and regions where air quality is a pressing issue. This information is crucial for directing resources and developing targeted interventions to improve air quality and protect public health.
#
# Overall, the EDA and global visualization offer a clear picture of air quality trends, pollutant contributions, and geographical patterns. These insights are instrumental for shaping environmental policies, guiding pollution control efforts, and identifying areas for further research and intervention.
